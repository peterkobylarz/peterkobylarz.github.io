# %%
import os
from glob import glob
import pathlib
import shutil

import earthpy as et
import earthpy.earthexplorer as etee
import earthpy.spatial as es
import geopandas as gpd
import geoviews as gv
import holoviews as hv
import hvplot.pandas
import hvplot.xarray
import numpy as np
import pandas as pd
import panel as pn
import rioxarray as rxr
import rioxarray.merge as rxrm

data_dir = os.path.join(et.io.HOME, et.io.DATA_NAME)
oak_dir = os.path.join(data_dir, 'oakland-neighborhoods')
ndvi_dir = os.path.join(data_dir, 'oakland-green-space', 'processed')

for a_dir in [data_dir, oak_dir, ndvi_dir]:
    if not os.path.exists(a_dir):
        os.makedirs(a_dir)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='p1005'>
#   <div id="fe81bf7c-d819-4a6d-99bc-2ca0d8ff2318" data-root-id="p1005" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"9a50f76f-c1f1-453c-ab3e-6bfc83db1074":{"version":"3.3.0","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"p1005"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"p1006","attributes":{"plot_id":"p1005","comm_id":"9eb7bf7f3f4a41699a735d381305ce99","client_comm_id":"81d908bb5f784d6d9074a8ab18f23546"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"toggle_value1","properties":[{"name":"active_icons","kind":"Any","default":{"type":"map"}},{"name":"options","kind":"Any","default":{"type":"map","entries":[["favorite","heart"]]}},{"name":"value","kind":"Any","default":[]},{"name":"_reactions","kind":"Any","default":[]},{"name":"_base_url","kind":"Any","default":"https://tabler-icons.io/static/tabler-icons/icons/"}]},{"type":"model","name":"copy_to_clipboard1","properties":[{"name":"value","kind":"Any","default":null},{"name":"fill","kind":"Any","default":"none"}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{ ...
#   var render_items = [{"docid":"9a50f76f-c1f1-453c-ab3e-6bfc83db1074","roots":{"p1005":"fe81bf7c-d819-4a6d-99bc-2ca0d8ff2318"},"root_ids":["p1005"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# Download neighborhoods shapefile and create GDF of Oakland
oak_path = os.path.join(data_dir, 'earthpy-downloads', 'CEDA_Nhhods02', 'CEDA_Nhhods02', 'CEDA_Neighborhoods2002.shp')
if not os.path.exists(oak_path):
    oak_url = ('http://data.openoakland.org/sites/default/files/'
               'CEDA_Nhhods02.zip')
    oak_zip = et.data.get_data(url=oak_url)

oak_gdf = gpd.read_file(oak_path).set_index('NAME').to_crs(4326)
neigh_gdf = (
    oak_gdf.
    loc[['Montclair']]
)
oak_gdf
# Out:
#                                                           geometry
# NAME
# Montclair        POLYGON ((-122.21595 37.83218, -122.19901 37.8...
# Shepherd Canyon  POLYGON ((-122.20487 37.83064, -122.18881 37.8...
# Not Named6       POLYGON ((-122.23066 37.84902, -122.22917 37.8...
# Glen Highlands   POLYGON ((-122.22824 37.84579, -122.22517 37.8...
# Golden Gate      POLYGON ((-122.28252 37.83801, -122.28238 37.8...
# ...                                                            ...
# Waverly          POLYGON ((-122.26126 37.81146, -122.26096 37.8...
# Webster          POLYGON ((-122.16595 37.75329, -122.16635 37.7...
# Woodland         POLYGON ((-122.17760 37.75361, -122.17735 37.7...
# Woodminster      POLYGON ((-122.17843 37.80374, -122.18510 37.7...
# Upper Dimond     POLYGON ((-122.20013 37.79744, -122.20053 37.7...
#
# [133 rows x 1 columns]

# %%
def download_neighborhood_data(name, geometry, start, end):
    """
    Download NAIP raster for a given geometry, start date, and end date

    Parameters
    ==========
    name : str
      The name used to label the download
    geometry : shapely.POLYGON
      The geometry to derive the download extent from. 
      Must have a `.bounds` attribute.
    start : str
      The start date as 'YYYY-MM-DD'
    end : strL
      The end date as 'YYYY-MM-DD'

    Returns
    =======
    downloader : earthpy.earthexplorer.EarthExplorerDownloader
      Object with information about the download, including the data directory.
    """
    
    print(f'Downloading NAIP for {name}')
    bbox = etee.BBox(*geometry.bounds)
    print(geometry.bounds)
    #label = row.pri_neigh.lower().replace(' ', '-')
    naip_downloader = etee.EarthExplorerDownloader(
        dataset="NAIP", 
        label=name.lower().replace(' ', '-'), 
        bbox=bbox,
        start=start, 
        end=end,
        store_credential=True)
    #print(naip_downloader.label)
    #print(naip_downloader.bbox.urx, naip_downloader.bbox.ury)
    naip_downloader.submit_download_request()
    #naip_downloader.wait_for_available_downloads()
    naip_downloader.download(override=True)
    return naip_downloader

# %%
def load_and_merge_arrays(name):
    """
    Load in and merge downloaded arrays
    
    Parameters
    ==========
    name : str
      The name used to label the download

    Returns
    =======
    merge_da : rxr. DataArray
        DataArray with the merged data
    """
    
    print(f'Merging array for {name}')
    data_path = os.path.join(
        et.io.HOME, et.io.DATA_NAME,
        name.lower().replace(' ', '-'))
    tif_paths = glob(os.path.join(data_path, '*.tif'))
    das = [rxr.open_rasterio(tp, masked=True) for tp in tif_paths]
    merged_da = rxrm.merge_arrays(das)
    return merged_da

# %%
def calculate_ndvi_statistics(gdf, da, stats_path, override=False):
    """
    Calculate NDVI, then summarize and save statistics
    
    Uses downloaded National Agricultural Imagery Program (NAIP)
    data.
    
    Parameters
    ==========
    gdf : gpd.GeoDataFrame
      A geodataframe with a single row/neighborhood name/boundary
    da : rxr.DataArray
      Multispectral (NAIP) raster data
    stats_path : pathlike
      Path to the statistics CSV file
    """
    name = str(gdf.index[0])
    print(f'Calculate NDVI and statistics for {name}')
    # Caching for existing data
    file_is_empty = True
    if os.path.exists(stats_path):
        print('Stats file exists.')
        stats_df = pd.read_csv(stats_path)
        file_is_empty = len(stats_df)==0
        print(f'Stats file is empty? {file_is_empty}')
        
        if not file_is_empty:
            if (name in list(stats_df.neighborhood)) and (not override):
                print(f'Stats exist for {name}, skipping')
                return            
            
    reprojected_gdf = gdf.to_crs(da.rio.crs)
    # clip the NAIP tile to the bounds of the neighborhood gdf
    naip_crop_da = da.rio.clip_box(*reprojected_gdf.total_bounds)

    # Clip to extent of neighborhood
    naip_da = naip_crop_da.rio.clip(reprojected_gdf.geometry)

    # Calculate NDVI
    ndvi_da = (
        (naip_da.sel(band=4) - naip_da.sel(band=1))
        / (naip_da.sel(band=4) + naip_da.sel(band=1))
    )

    #Calculate NDVI stats for neighborhood and append to CSV
    print(f'Writing stats for {name}')
    mode = 'w' if file_is_empty else 'a'
    pd.DataFrame(dict(
        neighborhood=[name],
        ndvi_minimum=[float(ndvi_da.min())],
        ndvi_maximum=[float(ndvi_da.max())],
        ndvi_median=[float(ndvi_da.median())],
        ndvi_25pctl=[np.nanpercentile(ndvi_da.values, 25)],
        ndvi_75pctl=[np.nanpercentile(ndvi_da.values, 75)],
        ndvi_mean=[float(ndvi_da.mean())],
        ndvi_stddev=[float(ndvi_da.std())]
        )).to_csv(stats_path, mode='a', header=file_is_empty, index=False)

# %%
ndvi_stats_path = os.path.join(ndvi_dir, 'oakland_neighborhood-ndvi-stats.csv')

for neighborhood_name, details in oak_gdf.iterrows():
    if not os.path.exists(ndvi_stats_path):
        print('NDVI stats file does not exist...')
        ndvi_stats_df = pd.DataFrame()
    else:
        ndvi_stats_df = pd.read_csv(ndvi_stats_path, index_col="neighborhood")
    if neighborhood_name in ndvi_stats_df.index:
        print(f'Neighborhood stats for {neighborhood_name} have already been calculated. Skipping')
        continue
    
    try:
        downloader = download_neighborhood_data(
            neighborhood_name, details.geometry, '2021-01-01', '2021-12-31')
    
    except (ValueError, TypeError):
        print('Download not available. Try different date range.')
        try:
            downloader = download_neighborhood_data(
                neighborhood_name, details.geometry, '2022-01-01', '2022-12-31')
        except (ValueError, TypeError):
            print('Data cannot be found. Skipping neighborhood.')
            continue
    # downloader = download_neighborhood_data(
    #     neighborhood_name, details.geometry, '2022-01-01', '2022-12-31')
    merged_da = load_and_merge_arrays(neighborhood_name)
    calculate_ndvi_statistics(oak_gdf.loc[[neighborhood_name]], merged_da, ndvi_stats_path)
    del merged_da
    
    # shutil.rmtree(downloader.data_dir)
# Out:
# Neighborhood stats for Montclair have already been calculated. Skipping
# Neighborhood stats for Shepherd Canyon have already been calculated. Skipping
# Downloading NAIP for Not Named6
# (-122.23066288319785, 37.845140768917474, -122.20982320460696, 37.86375221520572)
# Login Successful.
# Searching datasets...
# Using dataset alias: naip
# Searching scenes...
# Found 0 scenes
# Download not available. Try different date range.
# Downloading NAIP for Not Named6
# (-122.23066288319785, 37.845140768917474, -122.20982320460696, 37.86375221520572)
# Login Successful.
# Searching datasets...
# Using dataset alias: naip
# Searching scenes...
# Found 1 scenes
# 1 products found.
# Downloads staging...
# Data cannot be found. Skipping neighborhood.
# Downloading NAIP for Glen Highlands
# (-122.22824182380305, 37.832882050236535, -122.21529841589657, 37.84704066614924)
# Login Successful.
# Searching datasets...
# Using dataset alias: naip
# Searching scenes...
# Found 0 scenes
# Download not available. Try different date range.
# Downloading NAIP for Glen Highlands
# (-122.22824182380305, 37.832882050236535, -122.21529841589657, 37.84704066614924)
# Login Successful.
# Searching datasets...
# Using dataset alias: naip
# Searching scenes...
# Found 1 scenes
# 1 products found.
# Downloads staging...
# Data cannot be found. Skipping neighborhood.
# Neighborhood stats for Golden Gate have already been calculated. Skipping
# Neighborhood stats for Paradise Park have already been calculated. Skipping
# Neighborhood stats for Santa Fe have already been calculated. Skipping
# Neighborhood stats for Sausal Creek have already been calculated. Skipping
# Neighborhood stats for Clinton have already been calculated. Skipping
# Neighborhood stats for Acorn/ Acorn Industrial have already been calculated. Skipping
# Neighborhood stats for Adams Point have already been calculated. Skipping
# Neighborhood stats for Allendale have already been calculated. Skipping
# Neighborhood stats for Arroyo Viejo have already been calculated. Skipping
# Neighborhood stats for Bancroft Business/ Havenscourt have already been calculated. Skipping
# Neighborhood stats for Bartlett have already been calculated. Skipping
# Neighborhood stats for Bella Vista have already been calculated. Skipping
# Neighborhood stats for Brookfield Village have already been calculated. Skipping
# Neighborhood stats for Bushrod have already been calculated. Skipping
# Neighborhood stats for Caballo Hills have already been calculated. Skipping
# Neighborhood stats for Castlemont have already been calculated. Skipping
# Neighborhood stats for Chabot Park have already been calculated. Skipping
# Neighborhood stats for Chinatown have already been calculated. Skipping
# Neighborhood stats for Civic Center have already been calculated. Skipping
# Neighborhood stats for Claremont have already been calculated. Skipping
# Neighborhood stats for Clawson have already been calculated. Skipping
# Neighborhood stats for Cleveland Heights have already been calculated. Skipping
# Neighborhood stats for Coliseum have already been calculated. Skipping
# Neighborhood stats for Coliseum Industrial have already been calculated. Skipping
# Neighborhood stats for Columbia Gardens have already been calculated. Skipping
# Neighborhood stats for Cox have already been calculated. Skipping
# Neighborhood stats for Crestmont have already been calculated. Skipping
# Neighborhood stats for Crocker Highland have already been calculated. Skipping
# Neighborhood stats for Dimond have already been calculated. Skipping
# Neighborhood stats for Downtown have already been calculated. Skipping
# Neighborhood stats for Durant Manor have already been calculated. Skipping
# Neighborhood stats for East Peralta have already been calculated. Skipping
# Neighborhood stats for Eastmont have already been calculated. Skipping
# Neighborhood stats for Eastmont Hills have already been calculated. Skipping
# Neighborhood stats for Elmhurst Park have already been calculated. Skipping
# Neighborhood stats for Fairfax have already been calculated. Skipping
# Neighborhood stats for Fairfax Business/  Wentworth/ Holland have already been calculated. Skipping
# Neighborhood stats for Fairview Park have already been calculated. Skipping
# Neighborhood stats for Fitchburg have already been calculated. Skipping
# Neighborhood stats for Foothill Square have already been calculated. Skipping
# Neighborhood stats for Forestland have already been calculated. Skipping
# Neighborhood stats for Fremont have already been calculated. Skipping
# Neighborhood stats for Frick have already been calculated. Skipping
# Neighborhood stats for Fruitvale Station have already been calculated. Skipping
# Neighborhood stats for Gaskill have already been calculated. Skipping
# Neighborhood stats for Glenview have already been calculated. Skipping
# Neighborhood stats for Golf Links have already been calculated. Skipping
# Neighborhood stats for Grand Lake have already been calculated. Skipping
# Neighborhood stats for Harrington have already been calculated. Skipping
# Neighborhood stats for Hawthorne have already been calculated. Skipping
# Neighborhood stats for Hegenberger have already been calculated. Skipping
# Neighborhood stats for Highland have already been calculated. Skipping
# Neighborhood stats for Highland Terrace have already been calculated. Skipping
# Downloading NAIP for Hiller Highlands
# (-122.23429996946844, 37.848406688046595, -122.22160657526611, 37.85741944847785)
# Login Successful.
# Searching datasets...
# Using dataset alias: naip
# Searching scenes...
# Found 0 scenes
# Download not available. Try different date range.
# Downloading NAIP for Hiller Highlands
# (-122.23429996946844, 37.848406688046595, -122.22160657526611, 37.85741944847785)
# Login Successful.
# Searching datasets...
# Using dataset alias: naip
# Searching scenes...
# Found 1 scenes
# 1 products found.
# Downloads staging...
# Data cannot be found. Skipping neighborhood.
# Neighborhood stats for Hoover/ Foster have already been calculated. Skipping
# Neighborhood stats for Iveywood have already been calculated. Skipping
# Neighborhood stats for Ivy Hill have already been calculated. Skipping
# Neighborhood stats for Jefferson have already been calculated. Skipping
# Neighborhood stats for Lakeshore have already been calculated. Skipping
# Neighborhood stats for Lakewide have already been calculated. Skipping
# Neighborhood stats for Las Palmas have already been calculated. Skipping
# Neighborhood stats for Laurel have already been calculated. Skipping
# Neighborhood stats for Leona Heights have already been calculated. Skipping
# Neighborhood stats for Lincoln Highlands have already been calculated. Skipping
# Neighborhood stats for Lockwood Tevis have already been calculated. Skipping
# Neighborhood stats for Longfellow have already been calculated. Skipping
# Neighborhood stats for Lynn/ Highland Park have already been calculated. Skipping
# Neighborhood stats for Maxwell Park have already been calculated. Skipping
# Neighborhood stats for McClymonds have already been calculated. Skipping
# Neighborhood stats for Melrose have already been calculated. Skipping
# Neighborhood stats for Merritt have already been calculated. Skipping
# Downloading NAIP for Merriwood
# (-122.2173495433387, 37.832183059519835, -122.19900592549006, 37.85342342978656)
# Login Successful.
# Searching datasets...
# Using dataset alias: naip
# Searching scenes...
# Found 0 scenes
# Download not available. Try different date range.
# Downloading NAIP for Merriwood
# (-122.2173495433387, 37.832183059519835, -122.19900592549006, 37.85342342978656)
# Login Successful.
# Searching datasets...
# Using dataset alias: naip
# Searching scenes...
# Found 1 scenes
# 1 products found.
# Downloads staging...
# Data cannot be found. Skipping neighborhood.
# Neighborhood stats for Mills College have already been calculated. Skipping
# Neighborhood stats for Millsmont have already been calculated. Skipping
# Downloading NAIP for Montclair Business
# (-122.21278941964609, 37.82444022896961, -122.20703824780607, 37.829666089837254)
# Login Successful.
# Searching datasets...
# Using dataset alias: naip
# Searching scenes...
# Found 0 scenes
# Download not available. Try different date range.
# Downloading NAIP for Montclair Business
# (-122.21278941964609, 37.82444022896961, -122.20703824780607, 37.829666089837254)
# Login Successful.
# Searching datasets...
# Using dataset alias: naip
# Searching scenes...
# Found 1 scenes
# 1 products found.
# Downloads staging...
# Data cannot be found. Skipping neighborhood.
# Neighborhood stats for Mosswood have already been calculated. Skipping
# Neighborhood stats for North Kennedy Tract have already been calculated. Skipping
# Neighborhood stats for North Stonehurst have already been calculated. Skipping
# Neighborhood stats for Northgate have already been calculated. Skipping
# Neighborhood stats for Not Named1 have already been calculated. Skipping
# Neighborhood stats for Not Named2 have already been calculated. Skipping
# Neighborhood stats for Not Named3 have already been calculated. Skipping
# Downloading NAIP for Not Named4
# (-122.2443622178306, 37.86061746686055, -122.2330908791665, 37.8661183331497)
# Login Successful.
# Searching datasets...
# Using dataset alias: naip
# Searching scenes...
# Found 0 scenes
# Download not available. Try different date range.
# Downloading NAIP for Not Named4
# (-122.2443622178306, 37.86061746686055, -122.2330908791665, 37.8661183331497)
# Login Successful.
# Searching datasets...
# Using dataset alias: naip
# Searching scenes...
# Found 1 scenes
# 1 products found.
# Downloads staging...
# Data cannot be found. Skipping neighborhood.
# Neighborhood stats for Not Named5 have already been calculated. Skipping
# Neighborhood stats for Not Named7 have already been calculated. Skipping
# Neighborhood stats for Not Named8 have already been calculated. Skipping
# Neighborhood stats for Oak Center have already been calculated. Skipping
# Neighborhood stats for Oak Tree have already been calculated. Skipping
# Neighborhood stats for Oakland Ave/ Harrison St have already been calculated. Skipping
# Neighborhood stats for Oakmore have already been calculated. Skipping
# Neighborhood stats for Old City/ Produce & Waterfront have already been calculated. Skipping
# Downloading NAIP for Panoramic Hill
# (-122.24466221113646, 37.86394530999924, -122.22724367229816, 37.86976812133036)
# Login Successful.
# Searching datasets...
# Using dataset alias: naip
# Searching scenes...
# Found 0 scenes
# Download not available. Try different date range.
# Downloading NAIP for Panoramic Hill
# (-122.24466221113646, 37.86394530999924, -122.22724367229816, 37.86976812133036)
# Login Successful.
# Searching datasets...
# Using dataset alias: naip
# Searching scenes...
# Found 1 scenes
# 1 products found.
# Downloads staging...
# Data cannot be found. Skipping neighborhood.
# Neighborhood stats for Patten have already been calculated. Skipping
# Neighborhood stats for Peralta/ Hacienda have already been calculated. Skipping
# Neighborhood stats for Peralta/ Laney have already been calculated. Skipping
# Neighborhood stats for Piedmont Avenue have already been calculated. Skipping
# Neighborhood stats for Piedmont Pines have already been calculated. Skipping
# Neighborhood stats for Pill Hill have already been calculated. Skipping
# Neighborhood stats for Prescott have already been calculated. Skipping
# Neighborhood stats for Produce & Waterfront have already been calculated. Skipping
# Neighborhood stats for Ralph Bunche have already been calculated. Skipping
# Neighborhood stats for Rancho San Antonio have already been calculated. Skipping
# Neighborhood stats for Redwood Heights have already been calculated. Skipping
# Neighborhood stats for Reservoir Hill/ Meadow Brook have already been calculated. Skipping
# Neighborhood stats for Rockridge have already been calculated. Skipping
# Neighborhood stats for San Pablo Gateway have already been calculated. Skipping
# Neighborhood stats for School have already been calculated. Skipping
# Neighborhood stats for Seminary have already been calculated. Skipping
# Neighborhood stats for Sequoyah have already been calculated. Skipping
# Neighborhood stats for Shafter have already been calculated. Skipping
# Neighborhood stats for Sheffield Village have already been calculated. Skipping
# Neighborhood stats for Skyline - Hillcrest Estates have already been calculated. Skipping
# Neighborhood stats for Sobrante Park have already been calculated. Skipping
# Neighborhood stats for South Kennedy Tract have already been calculated. Skipping
# Neighborhood stats for South Prescott have already been calculated. Skipping
# Neighborhood stats for South Stonehurst have already been calculated. Skipping
# Neighborhood stats for St. Elizabeth have already been calculated. Skipping
# Neighborhood stats for Temescal have already been calculated. Skipping
# Neighborhood stats for Toler Heights have already been calculated. Skipping
# Neighborhood stats for Trestle Glen have already been calculated. Skipping
# Neighborhood stats for Tuxedo have already been calculated. Skipping
# Neighborhood stats for Upper Laurel have already been calculated. Skipping
# Neighborhood stats for Upper Peralta Creek/ Bartlett have already been calculated. Skipping
# Neighborhood stats for Upper Rockridge have already been calculated. Skipping
# Neighborhood stats for Waverly have already been calculated. Skipping
# Neighborhood stats for Webster have already been calculated. Skipping
# Neighborhood stats for Woodland have already been calculated. Skipping
# Neighborhood stats for Woodminster have already been calculated. Skipping
# Neighborhood stats for Upper Dimond have already been calculated. Skipping

# %%
ndvi_stats_df = pd.read_csv(ndvi_stats_path, index_col="neighborhood")
chloropleth = gv.tile_sources.EsriNatGeo*gv.Polygons(
    oak_gdf.join(ndvi_stats_df, how='left'),
    vdims=['ndvi_mean']
)
hv.save(chloropleth, 'oakland_chloropleth.html')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 ndvi_stats_df = pd.read_csv(ndvi_stats_path, index_col="neighborhood")
#       2 chloropleth = gv.tile_sources.EsriNatGeo*gv.Polygons(
# ----> 3     chi_gdf.join(ndvi_stats_df, how='left'),
#       4     vdims=['ndvi_mean']
#       5 )
#       6 hv.save(chloropleth, 'oakland_chloropleth.html')
#
# NameError: name 'chi_gdf' is not defined
